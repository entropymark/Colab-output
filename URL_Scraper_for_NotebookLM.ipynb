# %% [markdown]
# <a href="https://colab.research.google.com/github/entropymark/Colab-output/blob/main/URL_Scraper_for_NotebookLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time
import sys

def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

def get_all_website_links(url):
    """
    Returns all URLs that is found on `url` in which it belongs to the same website
    """
    urls = set()
    try:
        # User Agent is important so websites don't block the script immediately
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers, timeout=10)
        response.encoding = 'utf-8' # Ensure correct encoding

        # If the page is not accessible, return empty
        if response.status_code != 200:
            print(f"  [!] Error accessing {url}: Status {response.status_code}")
            return urls

        soup = BeautifulSoup(response.text, "html.parser")

        # Find all link tags
        for a_tag in soup.findAll("a"):
            href = a_tag.attrs.get("href")
            if href == "" or href is None:
                continue

            # Join relative URLs (e.g. '/about') with base URL to make absolute
            href = urljoin(url, href)

            # Remove query parameters/anchors to clean up URLs (optional, helps deduplication)
            # href = href.split("?")[0].split("#")[0]
            # Note: Keeping queries for now as some sites rely on them for navigation

            parsed_href = urlparse(href)

            # Clean the URL (remove trailing slash for consistency)
            href = href.rstrip('/')

            # Validate URL and ensure we stay on the same domain (internal links only)
            if is_valid(href) and href not in urls:
                original_domain = urlparse(url).netloc
                target_domain = parsed_href.netloc

                # Check if domains match (handling subdomains slightly loosely)
                if original_domain in target_domain:
                    urls.add(href)

    except Exception as e:
        print(f"  [!] Error parsing {url}: {e}")

    return urls

def crawl(url, max_depth=2, max_urls=200):
    """
    Crawls a web page and extracts all links.

    :param url: The starting URL
    :param max_depth: How many clicks deep to go (1 = just the page, 2 = page + links on it, etc.)
    :param max_urls: Safety limit to stop the script from running forever
    """
    global visited_urls
    visited_urls = set()
    urls_to_visit = [(url, 0)] # Queue of (url, current_depth)
    visited_urls.add(url)

    print(f"[*] Starting crawl on: {url}")
    print(f"[*] Max Depth: {max_depth} | Max URLs limit: {max_urls}")
    print("-" * 50)

    processed_count = 0

    while urls_to_visit and processed_count < max_urls:
        current_url, current_depth = urls_to_visit.pop(0)

        print(f"[{processed_count + 1}] Crawling (Depth {current_depth}): {current_url}")

        # If we haven't reached max depth, look for more links
        if current_depth < max_depth:
            found_links = get_all_website_links(current_url)

            for link in found_links:
                if link not in visited_urls:
                    visited_urls.add(link)
                    urls_to_visit.append((link, current_depth + 1))

        processed_count += 1

        # Be polite to the server
        time.sleep(0.5)

    return visited_urls

def save_to_file(urls, filename="scraped_urls.txt"):
    """
    Saves the set of URLs to a text file.
    """
    try:
        with open(filename, "w", encoding='utf-8') as f:
            for url in sorted(urls):
                f.write(url + "\n")
        print("-" * 50)
        print(f"[*] Successfully saved {len(urls)} URLs to {filename}")
        print("[*] You can now upload this file to NotebookLM.")
    except Exception as e:
        print(f"[!] Error saving file: {e}")

if __name__ == "__main__":
    print("=== Website URL Scraper for NotebookLM ===")
    start_url = input("Enter the website URL to scrape (include http:// or https://): ").strip()

    # Defaults
    depth_input = input("Enter Depth (1=One Page, 2=Drill Down 1 Level, 3=Deep): [Default: 2] ")
    max_depth = int(depth_input) if depth_input.isdigit() else 2

    if not start_url.startswith("http"):
        print("Error: Please include http:// or https:// at the start of the URL.")
    else:
        # Run the crawler
        all_urls = crawl(start_url, max_depth=max_depth, max_urls=300)
        save_to_file(all_urls)
# Out:
# === Website URL Scraper for NotebookLM ===
# Enter the website URL to scrape (include http:// or https://): https://docs.cloud.google.com/vertex-ai/docs
# Enter Depth (1=One Page, 2=Drill Down 1 Level, 3=Deep): [Default: 2] 1
# [*] Starting crawl on: https://docs.cloud.google.com/vertex-ai/docs
# [*] Max Depth: 1 | Max URLs limit: 300
# --------------------------------------------------
# [1] Crawling (Depth 0): https://docs.cloud.google.com/vertex-ai/docs
# /tmp/ipython-input-719920600.py:35: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   for a_tag in soup.findAll("a"):
# [2] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/model-registry/delete-model
# [3] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/serve-historical-features
# [4] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/explainable-ai/limitations
# [5] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/update-featuregroup
# [6] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/image-classification-custom
# [7] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/cloud-storage-file-system
# [8] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/image-data/classification/prepare-data
# [9] Crawling (Depth 1): https://docs.cloud.google.com/video-stitcher/docs/concepts/overview
# [10] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/jupyter-notebooks
# [11] Crawling (Depth 1): https://docs.cloud.google.com/docs
# [12] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/datasets/create-annotation-set
# [13] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/create-dataset
# [14] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/quotas
# [15] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/interfaces
# [16] Crawling (Depth 1): https://docs.cloud.google.com/agent-assist/docs
# [17] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/python-sdk/use-vertex-ai-sdk
# [18] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/introduction
# [19] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/use-reservations
# [20] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/forecasting/hierarchical
# [21] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/serve-llama3-with-saxml-tpu
# [22] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/ml-metadata/system-schemas
# [23] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials
# [24] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/delete-pipeline-runs
# [25] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/image-data/object-detection/get-predictions
# [26] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-track-params-metrics-custom-training
# [27] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/open-source/ray-on-vertex-ai/bigquery-integration
# [28] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/using-nvidia-triton
# [29] Crawling (Depth 1): https://docs.cloud.google.com/docs/samples
# [30] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/create-console-quickstart
# [31] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/export/export-model-tabular
# [32] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/overview
# [33] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/image-data/object-detection/evaluate-model
# [34] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/evaluation/data-bias-metrics
# [35] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search-2/indexes/indexes
# [36] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/cancel-pipeline-runs
# [37] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/networking
# [38] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/image-classification-automl/error-analysis
# [39] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/intro-vertex-ai-experiments
# [40] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/migrate
# [41] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/create-python-pre-built-container
# [42] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/visualize-pipeline
# [43] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/save-to-github
# [44] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/using-private-endpoints
# [45] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training-overview#image_data
# [46] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/training-clusters/visualizing-jobs-with-tensorboard
# [47] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/custom-training-methods
# [48] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/image-classification-custom/serving
# [49] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-tensorboard-hyperparameter-tuning-hparam-dashboard
# [50] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/configuring-indexes
# [51] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/prepare-data-source
# [52] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/psc-endpoints
# [53] Crawling (Depth 1): https://docs.cloud.google.com/document-ai/docs/workbench/build-custom-processor
# [54] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/python-sdk/training-classes
# [55] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/private-service-connect
# [56] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/access-transparency
# [57] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/image-data/classification/train-model
# [58] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/delete-feature-values
# [59] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-tensorboard-profiler-training-performance
# [60] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/explainable-ai/visualization-settings
# [61] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/start/training-guide
# [62] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/add-pipelinerun-experiment
# [63] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/neural-architecture-search/pytorch-efficient-training
# [64] Crawling (Depth 1): https://docs.cloud.google.com/docs/costs-usage
# [65] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/managing-features
# [66] Crawling (Depth 1): https://docs.cloud.google.com/release-notes
# [67] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/introduction
# [68] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/configure-compute
# [69] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/configure-retries
# [70] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/ml-metadata/introduction
# [71] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-tensorboard-custom-training-custom-container
# [72] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/e2e-automl
# [73] Crawling (Depth 1): https://docs.cloud.google.com/dialogflow/cx/docs
# [74] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/vpc
# [75] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/dataproc
# [76] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/open-source/ray-on-vertex-ai/set-up
# [77] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/colab/create-runtime
# [78] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/generative-ai/docs/start/quickstart
# [79] Crawling (Depth 1): https://docs.cloud.google.com/financial-services/anti-money-laundering/docs/concepts/overview
# [80] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/terraform
# [81] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/schedule-jobs-dws
# [82] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/start/pytorch
# [83] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/python-sdk/python-sdk-class-overview
# [84] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/private-service-connect
# [85] Crawling (Depth 1): https://docs.cloud.google.com/healthcare-api/docs/concepts/nlp
# [86] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/image-classification-automl/overview
# [87] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-delete-outdated-tb-experiments
# [88] Crawling (Depth 1): https://docs.cloud.google.com/docs/security
# [89] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/get-online-predictions
# [90] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs#main-content
# [91] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/audit-logging
# [92] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/log-data
# [93] Crawling (Depth 1): https://docs.cloud.google.com/docs/migration
# [94] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/monitor-health
# [95] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/iam-permissions
# [96] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/neural-architecture-search/nas-tutorials
# [97] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/custom-training-pipelines/image-classification
# [98] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/custom-container
# [99] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/format-structure
# [100] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/monitor
# [101] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/migrate
# [102] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/email-notifications
# [103] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/export-features
# [104] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/get-batch-model-garden
# [105] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/evaluation/model-bias-metrics
# [106] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/serve-gemma-with-saxml-tpu
# [107] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/glossary
# [108] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/create-experiment
# [109] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/delete-feature
# [110] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/manage-access-jupyterlab
# [111] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/search-resources
# [112] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/model-monitoring/model-monitoring-batch-predictions
# [113] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/optimized-tensorflow-runtime
# [114] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/explainable-ai/configuring-explanations-feature-based
# [115] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/overview
# [116] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/evaluation/introduction
# [117] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/list-featuregroups
# [118] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/monitoring
# [119] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/neural-architecture-search/suggested-workflow
# [120] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/migrate-kfp
# [121] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/build-own-components
# [122] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/introduction
# [123] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/python-sdk/data-classes
# [124] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search-2/support
# [125] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/deploy-index-vpc
# [126] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/jwt-auth?topic_type=authentication
# [127] Crawling (Depth 1): https://docs.cloud.google.com/text-to-speech
# [128] Crawling (Depth 1): https://docs.cloud.google.com/speech-to-text/priv
# [129] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/start/introduction-interfaces
# [130] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/shielded-vm
# [131] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/autolog-data
# [132] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/python-sdk/model-classes
# [133] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/idle-shutdown
# [134] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/configure-training-script
# [135] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/use-reservations
# [136] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/forecasting-prophet
# [137] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/log-models-exp-run
# [138] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-tensorboard-profiler-custom-training-prebuilt
# [139] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/use-reservations-batch
# [140] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/source-data
# [141] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/generative-ai/docs/extensions/overview
# [142] Crawling (Depth 1): https://docs.cloud.google.com/architecture
# [143] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/serverless-spark
# [144] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vizier/vizier-notebook-tutorials
# [145] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction
# [146] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search-2/query-search/query
# [147] Crawling (Depth 1): https://docs.cloud.google.com/docs/application-hosting
# [148] Crawling (Depth 1): https://docs.cloud.google.com/docs/networking
# [149] Crawling (Depth 1): https://docs.cloud.google.com/colab/docs/introduction
# [150] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/hyperparameter-tuning-overview
# [151] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/online-prediction-logging
# [152] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/custom-container-requirements
# [153] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular101
# [154] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore
# [155] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/create-manage-index
# [156] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/configure-caching
# [157] Crawling (Depth 1): https://docs.cloud.google.com/document-ai/docs/enterprise-document-ocr
# [158] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/view-endpoint-metrics
# [159] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/using-private-ip
# [160] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/forecasting-online-predictions
# [161] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/model-registry/versioning
# [162] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/route-pubsub
# [163] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/run-training-job-experiments
# [164] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/quotas
# [165] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/create
# [166] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/custom-service-account
# [167] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/generative-ai/docs/embeddings/get-text-embeddings
# [168] Crawling (Depth 1): https://docs.cloud.google.com/architecture/data-science-with-r-on-gcp-eda
# [169] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/open-source/ray-on-vertex-ai/delete-cluster
# [170] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/tensorboard-introduction
# [171] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/evaluation/using-model-evaluation
# [172] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/overview
# [173] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/datasets/export-metadata-annotations
# [174] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/monitor-health
# [175] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/timeseries-insights
# [176] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/training-clusters/run-prebuilt-workloads
# [177] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/start/explore-models
# [178] Crawling (Depth 1): https://docs.cloud.google.com/vision-ai/docs/overview
# [179] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/reservations
# [180] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/tabnet-batch-predictions
# [181] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/training-clusters/overview
# [182] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/forecasting-train
# [183] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/service-accounts
# [184] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/setup
# [185] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-tensorboard-custom-training-prebuilt-container
# [186] Crawling (Depth 1): https://docs.cloud.google.com/docs/devtools
# [187] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/upgrade
# [188] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/model-monitoring/schemas
# [189] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/image-classification-automl/training
# [190] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/tensorboard-profiler
# [191] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/serve-feature-values
# [192] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/managing-featurestores
# [193] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/generative-ai/docs/models
# [194] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/datasets/label-using-console
# [195] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/understanding-training-service
# [196] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/ingesting-batch
# [197] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/schedule-pipeline-run
# [198] Crawling (Depth 1): https://docs.cloud.google.com/docs/storage
# [199] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/ssh-access
# [200] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/executor
# [201] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/beginner/bqml
# [202] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/classification-regression/train-model
# [203] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/colab/connect-to-runtime
# [204] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/neural-architecture-search/overview
# [205] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/explainable-ai/overview
# [206] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/vpc-standalone
# [207] Crawling (Depth 1): https://docs.cloud.google.com/docs/dhm-cloud
# [208] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/manage-environment
# [209] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/open-source/ray-on-vertex-ai/tutorials/jupyter-notebooks
# [210] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/view-dcgm-metrics
# [211] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/tabular-automl/setup
# [212] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/samples
# [213] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/tabular-bq-prediction/train-and-deploy-model
# [214] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/model-registry/model-registry-bqml
# [215] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/open-source/ray-on-vertex-ai/deploy-predict
# [216] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/troubleshooting-workbench#user-managed-notebooks
# [217] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/migrate-to-instances
# [218] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/notebooks
# [219] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/support
# [220] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/try-it
# [221] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/deployment
# [222] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/neural-architecture-search/pre-built-trainer
# [223] Crawling (Depth 1): https://docs.cloud.google.com/docs/get-started
# [224] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/using-metadata
# [225] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/iam
# [226] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/save-to-github
# [227] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/start/use-terraform-vertex-ai
# [228] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/model-registry/model-labels
# [229] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/datasets/manage-dataset-versions
# [230] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/persistent-resource-delete
# [231] Crawling (Depth 1): https://docs.cloud.google.com/docs/generative-ai
# [232] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/vpc-standalone
# [233] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/psc-i-egress
# [234] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/ml-metadata/ml-metadata-notebook-tutorials
# [235] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/netsec-overview
# [236] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-model-training
# [237] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/migrate-to-instances
# [238] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/training-clusters/storage
# [239] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/wide-and-deep
# [240] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/generative-ai/docs/learn/overview
# [241] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/data-preparation-overview
# [242] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/secret-manager
# [243] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/visualize-data-bigquery
# [244] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/ml-metadata/managing-metadata
# [245] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/automl-training-overview
# [246] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/python-sdk/use-vertex-ai-python-sdk
# [247] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/delete-featuregroup
# [248] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/audit-logging
# [249] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/custom-constraints
# [250] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/forecasting-arima/overview
# [251] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/forecasting/train-model
# [252] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tutorials/tabular-automl/cleanup
# [253] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/containers-overview
# [254] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/create-training-pipeline
# [255] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/shut-down
# [256] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/instances/add-environment
# [257] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/use-flex-start-vms
# [258] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/feature-labels
# [259] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/bigquery
# [260] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/custom-constraints
# [261] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/monitor-features
# [262] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/predictions/use-custom-container
# [263] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/vpc-service-controls
# [264] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search-2/collections/collections
# [265] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/data-splits
# [266] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/create-featureview
# [267] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/ml-metadata/analyzing
# [268] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/resource-policy
# [269] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/export/export-edge-model
# [270] Crawling (Depth 1): https://docs.cloud.google.com/speech-to-text/ondevice
# [271] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/use-template-gallery
# [272] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/overview
# [273] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/open-source/ray-on-vertex-ai/run-spark-on-ray
# [274] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/notebooks
# [275] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/vpc-psc-i-setup
# [276] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/tabnet
# [277] Crawling (Depth 1): https://docs.cloud.google.com/docs/application-development
# [278] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/vpcsc-public-endpoint
# [279] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/general/vpc-psc-i-multicloud-access
# [280] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/explainable-ai/configuring-explanations-example-based
# [281] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/model-monitoring/using-model-monitoring
# [282] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/update-onlinestore
# [283] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/support/getting-support
# [284] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/forecasting/create-dataset
# [285] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/e2e-automl-train
# [286] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/training-clusters/get-started
# [287] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/storage-optimized-vector-search
# [288] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/serving-online
# [289] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/continuous-training-tutorial
# [290] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/tabular-data/tabular-workflows/wide-and-deep-online-predictions
# [291] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/user-managed/service-perimeter
# [292] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/pipelines/components-quickstart
# [293] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/evaluation/model-evaluation-notebook-tutorials
# [294] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/workbench/managed/access-control
# [295] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/training/training-clusters/orchestration
# [296] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/experiments/user-journey/uj-tensorboard-integration-pipelines
# [297] Crawling (Depth 1): https://docs.cloud.google.com/document-warehouse/docs/overview
# [298] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/featurestore/latest/embeddings-search
# [299] Crawling (Depth 1): https://docs.cloud.google.com/vertex-ai/docs/vector-search/jwt-auth
# [300] Crawling (Depth 1): https://docs.cloud.google.com/healthcare-api/docs/introduction
# --------------------------------------------------
# [*] Successfully saved 640 URLs to scraped_urls.txt
# [*] You can now upload this file to NotebookLM.
